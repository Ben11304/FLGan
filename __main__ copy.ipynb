# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import LabelEncoder
import numpy as np
from data_work import data_split
from data_work import processed
from data_work import analyse_dataset
from data_work import set_data
from sklearn.model_selection import train_test_split
df=pd.read_csv("/Users/mac/Dev/data/dta_IoT/new2test.csv")
#delete all null columns
id=[16,17,21,22,23,24]
col=df.columns
for idx in id:
    df=df.drop(col[idx],axis=1)
data=processed(df,"subcategory ")
names=["attack","category","subcategory "]
analyse_dataset(data,names)
# Out:
# thống kê nhãn attack:
# 1 6095
# 0 931
# thống kê nhãn category:
# 3 1109
# 2 1992
# 0 2994
# 1 931
# thống kê nhãn subcategory :
# 2 995
# 4 992
# 5 1000
# 6 1000
# 3 931
# 1 994
# 7 1000
# 0 114
# [1, 0, 3, 2, 0, 1, 2, 4, 5, 6, 3, 1, 7, 0]

# %%
traindata,test_data=train_test_split(data,test_size=0.4,random_state=42,stratify=data['subcategory '])
data = traindata.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)
client_data,server_data=train_test_split(traindata,test_size=0.001,random_state=42)
client_data = client_data.reset_index(drop=True)
server_data = server_data.reset_index(drop=True)

# %%
analyse_dataset(test_data,names)
# Out:
# thống kê nhãn attack:
# 1 2439
# 0 372
# thống kê nhãn category:
# 3 444
# 0 1198
# 1 372
# 2 797
# thống kê nhãn subcategory :
# 2 398
# 1 398
# 3 372
# 6 400
# 4 397
# 5 400
# 7 400
# 0 46
# [1, 0, 3, 0, 1, 2, 2, 1, 3, 6, 4, 5, 7, 0]

# %%
analyse_dataset(server_data,names)
# Out:
# thống kê nhãn attack:
# 0 2
# 1 3
# thống kê nhãn category:
# 1 2
# 3 2
# 0 1
# thống kê nhãn subcategory :
# 3 2
# 2 2
# 6 1
# [0, 1, 1, 3, 0, 3, 2, 6]

# %%
testdata_list=set_data([test_data])[0]

#chia data thành list gồm 2 phàn tử [0] là X, [1] là y
# Out:
# len X 2811, len y 2811

# %% [markdown]
# # iid dataset setup

# %%
trainloaders,testloaders=data_split(client_data,"subcategory ",8,0.1,IID=1)
#4 clients
# Out:
# prepairing IID dataset
# len of client data :4210, len of each subdata : 526
# client number 1 : train(474), val(52)
# client number 2 : train(474), val(52)
# client number 3 : train(474), val(52)
# client number 4 : train(474), val(52)
# client number 5 : train(474), val(52)
# client number 6 : train(474), val(52)
# client number 7 : train(474), val(52)
# client number 8 : train(474), val(52)

# %%
BATCH_SIZE=10
NUM_CLIENTS=4
NUM_ROUNDS =3

# %%
from model import Net

# %%
trainlist=set_data(trainloaders)
testlist=set_data(testloaders)
# Out:
# len X 474, len y 474
# len X 474, len y 474
# len X 474, len y 474
# len X 474, len y 474
# len X 474, len y 474
# len X 474, len y 474
# len X 474, len y 474
# len X 474, len y 474
# len X 52, len y 52
# len X 52, len y 52
# len X 52, len y 52
# len X 52, len y 52
# len X 52, len y 52
# len X 52, len y 52
# len X 52, len y 52
# len X 52, len y 52

# %%
from sklearn.decomposition import PCA


# Khởi tạo PCA với số thành phần chính cần giữ lại là 2
pca = PCA(n_components=2)

# Thực hiện phân tích PCA trên dữ liệu
X_reduced = pca.fit_transform(trainlist[1][0])
import matplotlib.pyplot as plt


# Plot dữ liệu
colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'w'] # Màu sắc tương ứng với các nhãn
for i in range(len(X_reduced)):
    plt.scatter(X_reduced[i][0], X_reduced[i][1], color=colors[trainlist[1][1][i]])

# Đặt nhãn cho trục x và y
plt.xlabel('X1')
plt.ylabel('X2')

# Đặt tiêu đề cho đồ thị
plt.title('Biểu đồ dữ liệu')

# Hiển thị đồ thị
plt.show()

# %% [markdown]
# ##Create model function

# %%
import torch
import torch.nn as nn

# %%
trainloaders,testloaders=data_split(client_data,"subcategory ",15,0.1,IID=0)
# Out:
# prepairing non IID dataset
# len of client data :4200, len of each subdata : 280
# client number 1 : train(252), val(28)
# client number 2 : train(252), val(28)
# client number 3 : train(252), val(28)
# client number 4 : train(252), val(28)
# client number 5 : train(252), val(28)
# client number 6 : train(252), val(28)
# client number 7 : train(252), val(28)
# client number 8 : train(252), val(28)
# client number 9 : train(252), val(28)
# client number 10 : train(252), val(28)
# client number 11 : train(252), val(28)
# client number 12 : train(252), val(28)
# client number 13 : train(252), val(28)
# client number 14 : train(252), val(28)
# client number 15 : train(252), val(28)

# %%
trainlist=set_data(trainloaders)
testlist=set_data(testloaders)
# Out:
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 252, len y 252
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28
# len X 28, len y 28

# %%
names=["subcategory "]
a=analyse_dataset(trainloaders[7],names)
print(a)
# Out:
# thống kê nhãn subcategory :
# 4 252
# [4]

# %%
from CGan import CGAN

# %% [markdown]
# ##Client

# %%
class client():
    def __init__(self,cid,net):
        self.cid=cid 
        self.model=net
        self.trainset=net.dataset
        #self.testset=testset
        self.client_label=analyse_dataset(trainloaders[cid],["subcategory "])

    def get_parameter(self):
        return self.model.get_parameter()
    
    def fit(self, config ):
        # Read values from config
        server_round = config["server_round"]
        local_epochs = config["local_epochs"]
        #print command to know that the config of training process
        print(f"[Client {self.cid}, round {server_round}] fit, config: {config}")
        #num_examples_train = self.trainset.size[1]
        history=self.model.train()
        results = {
            "D_loss": history["D_loss"][-1],
            "G_loss": history["G_loss"][-1],
        }
        return results
    
    def Gen_fake_data(self,y):
        if isinstance(y, pd.DataFrame):
            y=torch.tensor(y.values)
        len=y.shape[0]
        z= torch.rand(len,self.model.z_dim)
        fdata=self.model.G(z,y)
        return fdata

# %%
class Args:
    def __init__(self,data_cid):
        self.epoch = 10
        self.batch_size = 5
        self.dataset = torch.tensor(trainloaders[data_cid].values)
        self.save_dir=" "
        self.result_dir=" "
        self.log_dir = 'logs/'
        self.gpu_mode = True
        self.gan_type = 'cGAN'
        self.z_dim = 10
        self.n_class = 8
        self.sample_num = self.n_class ** 2
        self.lrG=0.0001
        self.lrD=0.0001
        self.n_epochs=self.n_class
        self.n_classes=self.n_class
        self.noise_size=self.z_dim
        self.n_features=28

# %%
config = {
    "server_round": 3,
    "local_epochs": 10
}

# %%
def client_fn(cid: str):  
    """Create a Flower client representing a single organization."""
    # Load model
    args=Args(cid)
    print(cid)
    net=CGAN(args)
    # Create a  single Flower client representing a single organization
    return client(cid, net)

# %%
print(len(test_data))
# Out:
# 2811

# %%
te=torch.tensor(server_data.values)
X_te=te[:,1:]
y_te=te[:,:1]
print(len(X_te))
y_te=y_te.squeeze().tolist()
y_te=torch.tensor(y_te)
mul=Net(0.00)
mul.Cross_validation(X_te,y_te,2,0.0003)
_,accuracy=mul.evaluate(testdata_list[0],testdata_list[1])
print(f"total accuracy : {accuracy}")
# Out:
# 5
# length of trainset 2, length of testset3
# Accuracy for fold 1 : 0.0
# length of trainset 3, length of testset2
# Accuracy for fold 2 : 0.5
# total accuracy : 0.1664887940234792

# %% [markdown]
# ##Server

# %%
import random
class server():
    def __init__(self):
        self.server_model=Net(0.00)
        self.trainset=torch.tensor(server_data.values)
        self.testset=testdata_list
        self.clients=[]
        n_clients=15
        for i in range(n_clients):
            client=client_fn(i)
            self.clients.append(client)

    
    #def fit_round():
    def simulation(self,rounds):
        
        for round in range(rounds):
            total_fake=[]
            for i in range(len(self.clients)):
                #kết hợp data sever và xáo trộn
                data=torch.cat((self.clients[i].model.dataset, self.trainset), dim=0)
                indices = list(range(data.size(0)))
                random.shuffle(indices)
                shuffled_data = data[indices, :]
                self.clients[i].model.dataset= shuffled_data
                #D_parameters,G_parameters=client.get_parameter()
                config = {
                            "server_round": round,
                            "local_epochs": 5
                        }
                results=self.clients[i].fit(config)
                print(results)
                
                y=self.clients[i].client_label*100

                #tạo data giả
                y=torch.tensor(y, dtype=torch.long)
                data_fake=self.clients[i].Gen_fake_data(y)
                data_fake=torch.cat((y.unsqueeze(1), data_fake), dim=1)
                total_fake.append(data_fake)
            round_data = torch.empty(1, 28)
            for fake in total_fake:
                fake=fake.detach()
                round_data=torch.cat((round_data,fake), dim=0)
            print(f"number of synthetic data : {len(round_data)}")
            
            X=self.trainset[:,1:]
            y=self.trainset[:,:1]
            y=y.squeeze().tolist()
            y=torch.tensor(y)
            #self.server_model.Cross_validation(X,y,5,0.003)
            self.server_model.Cross_validation(X,y,5,0.0003)
            _,accuracy=self.server_model.evaluate(self.testset[0],self.testset[1])
            print(f"round{round} accuracy:{accuracy}")

# %%
fed=server()
# Out:
# 0
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 1 196
# 0 56
# 1
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 1 252
# 2
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 2 153
# 1 99
# 3
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 2 252
# 4
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 3 128
# 2 124
# 5
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 3 252
# 6
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 3 121
# 4 131
# 7
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 4 252
# 8
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 4 150
# 5 102
# 9
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 5 252
# 10
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 5 184
# 6 68
# 11
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 6 252
# 12
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 6 220
# 7 32
# 13
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 7 252
# 14
# ---------- Networks architecture -------------
# Gen(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=18, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Linear(in_features=512, out_features=1028, bias=True)
#     (9): BatchNorm1d(1028, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Linear(in_features=1028, out_features=28, bias=True)
#     (12): BatchNorm1d(28, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2)
#   )
# )
# Total number of parameters: 726928
# Dis(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=512, out_features=512, bias=True)
#     (6): Dropout(p=0.4, inplace=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )
# Total number of parameters: 544833
# -----------------------------------------------
# thống kê nhãn subcategory :
# 7 252

# %%
fed.simulation(9)
# Out:
# [Client 0, round 0] fit, config: {'server_round': 0, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss:
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99984884
# Avg one epoch time: 1.28, total 10 epochs time: 12.76
# Training finish!
# {'D_loss': 1.1236778174605888e-09, 'G_loss': 0.9998488426208496}
# [Client 14, round 0] fit, config: {'server_round': 0, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.02331127, G_loss: 0.71955329
# Epoch: [ 2] [  50/  50] D_loss: 0.00138262, G_loss: 0.91975814
# Epoch: [ 3] [  50/  50] D_loss: 0.00019151, G_loss: 0.96974313
# Epoch: [ 4] [  50/  50] D_loss: 0.00002984, G_loss: 0.98574656
# Epoch: [ 5] [  50/  50] D_loss: 0.00000434, G_loss: 0.99699306
# Epoch: [ 6] [  50/  50] D_loss: 0.00000036, G_loss: 0.99930370
# Epoch: [ 7] [  50/  50] D_loss: 0.00000012, G_loss: 0.99978292
# Epoch: [ 8] [  50/  50] D_loss: 0.00000001, G_loss: 0.99984610
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99986124
# Epoch: [10] [  50/  50] D_loss: 0.00000001, G_loss: 0.99992543
# Avg one epoch time: 1.41, total 10 epochs time: 14.10
# Training finish!
# {'D_loss': 5.530618629734363e-09, 'G_loss': 0.999925434589386}
# length of trainset 1764, length of testset441
# Accuracy for fold 1 : 0.19954648526077098
# length of trainset 1764, length of testset441
# Accuracy for fold 2 : 0.3287981859410431
# length of trainset 1764, length of testset441
# Accuracy for fold 3 : 0.23809523809523808
# length of trainset 1764, length of testset441
# Accuracy for fold 4 : 0.3197278911564626
# length of trainset 1764, length of testset441
# Accuracy for fold 5 : 0.46485260770975056
# round0 accuracy:0.3415154749199573
# [Client 0, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 1.00000000, G_loss: 0.99996966
# Epoch: [ 2] [  50/  50] D_loss: 1.00000000, G_loss: 0.99991858
# Epoch: [ 3] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998987
# Epoch: [ 4] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997824
# Epoch: [ 5] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997389
# Epoch: [ 6] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997741
# Epoch: [ 7] [  50/  50] D_loss: 1.00000000, G_loss: 0.99996632
# Epoch: [ 8] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999249
# Epoch: [ 9] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998128
# Epoch: [10] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999034
# Avg one epoch time: 1.19, total 10 epochs time: 11.93
# Training finish!
# {'D_loss': 1.0, 'G_loss': 0.9999903440475464}
# [Client 1, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99994355
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995661
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996722
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995768
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996424
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998742
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997842
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998105
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998891
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998367
# Avg one epoch time: 1.11, total 10 epochs time: 11.07
# Training finish!
# {'D_loss': 1.6435805494374733e-10, 'G_loss': 0.9999836683273315}
# [Client 2, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997520
# Epoch: [ 2] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998343
# Epoch: [ 3] [  50/  50] D_loss: 1.00000000, G_loss: 0.99996507
# Epoch: [ 4] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998635
# Epoch: [ 5] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998111
# Epoch: [ 6] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998581
# Epoch: [ 7] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997902
# Epoch: [ 8] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999219
# Epoch: [ 9] [  50/  50] D_loss: 1.00000000, G_loss: 0.99996853
# Epoch: [10] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999255
# Avg one epoch time: 1.23, total 10 epochs time: 12.30
# Training finish!
# {'D_loss': 1.0, 'G_loss': 0.9999925494194031}
# [Client 3, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997008
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99992895
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99993360
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997389
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998534
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996984
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998343
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998474
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997646
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99
round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000001, G_loss: 0.99983519
# Epoch: [ 2] [  50/  50] D_loss: 0.00000005, G_loss: 0.99990499
# Epoch: [ 3] [  50/  50] D_loss: 0.00000001, G_loss: 0.99990523
# Epoch: [ 4] [  50/  50] D_loss: 0.00000001, G_loss: 0.99995404
# Epoch: [ 5] [  50/  50] D_loss: 0.00000005, G_loss: 0.99994564
# Epoch: [ 6] [  50/  50] D_loss: 0.00000001, G_loss: 0.99994755
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998093
# Epoch: [ 8] [  50/  50] D_loss: 0.00000003, G_loss: 0.99999064
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99990958
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998820
# Avg one epoch time: 1.30, total 10 epochs time: 12.98
# Training finish!
# {'D_loss': 3.149077526520827e-11, 'G_loss': 0.9999881982803345}
# [Client 10, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000001, G_loss: 0.99982244
# Epoch: [ 2] [  50/  50] D_loss: 0.00000001, G_loss: 0.99984777
# Epoch: [ 3] [  50/  50] D_loss: 0.00000002, G_loss: 0.99983084
# Epoch: [ 4] [  50/  50] D_loss: 0.00000001, G_loss: 0.99993861
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99991971
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995422
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99986237
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996912
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997312
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99985516
# Avg one epoch time: 1.26, total 10 epochs time: 12.59
# Training finish!
# {'D_loss': 8.218994373976329e-10, 'G_loss': 0.9998551607131958}
# [Client 11, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997491
# Epoch: [ 2] [  50/  50] D_loss: 1.00000000, G_loss: 0.99996603
# Epoch: [ 3] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997491
# Epoch: [ 4] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998474
# Epoch: [ 5] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998724
# Epoch: [ 6] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998713
# Epoch: [ 7] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998552
# Epoch: [ 8] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998742
# Epoch: [ 9] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997902
# Epoch: [10] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998665
# Avg one epoch time: 1.50, total 10 epochs time: 14.99
# Training finish!
# {'D_loss': 1.0, 'G_loss': 0.9999866485595703}
# [Client 12, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 1.00000000, G_loss: 0.99994087
# Epoch: [ 2] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997127
# Epoch: [ 3] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998939
# Epoch: [ 4] [  50/  50] D_loss: 1.00000000, G_loss: 0.99996328
# Epoch: [ 5] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998504
# Epoch: [ 6] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997634
# Epoch: [ 7] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998856
# Epoch: [ 8] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998206
# Epoch: [ 9] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998534
# Epoch: [10] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998885
# Avg one epoch time: 1.42, total 10 epochs time: 14.16
# Training finish!
# {'D_loss': 1.0, 'G_loss': 0.999988853931427}
# [Client 13, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995422
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99994552
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997103
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997890
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997711
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995023
# Epoch: [ 7] [  50/  50] D_loss: 0.00000001, G_loss: 0.99992961
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997407
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999511
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997663
# Avg one epoch time: 1.27, total 10 epochs time: 12.69
# Training finish!
# {'D_loss': 1.4373652268417914e-10, 'G_loss': 0.999976634979248}
# [Client 14, round 1] fit, config: {'server_round': 1, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99993008
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995375
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995536
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999124
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998075
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996281
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998951
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998987
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996489
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999475
# Avg one epoch time: 1.34, total 10 epochs time: 13.40
# Training finish!
# {'D_loss': 2.0966765823526856e-10, 'G_loss': 0.9999947547912598}
# length of trainset 3524, length of testset881
# Accuracy for fold 1 : 0.4801362088535755
# length of trainset 3524, length of testset881
# Accuracy for fold 2 : 0.5175936435868331
# length of trainset 3524, length of testset881
# Accuracy for fold 3 : 0.4858115777525539
# length of trainset 3524, length of testset881
# Accuracy for fold 4 : 0.4869466515323496
# length of trainset 3524, length of testset881
# Accuracy for fold 5 : 0.5414301929625426
# round1 accuracy:0.42653859836357166
# [Client 0, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998283
# Epoch: [ 2] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999028
# Epoch: [ 3] [  50/  50] D_loss: 1.00000000, G_loss: 0.99996984
# Epoch: [ 4] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998635
# Epoch: [ 5] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997348
# Epoch: [ 6] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998558
# Epoch: [ 7] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998224
# Epoch: [ 8] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998939
# Epoch: [ 9] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999416
# Epoch: [10] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998236
# Avg one epoch time: 1.26, total 10 epochs time: 12.56
# Training finish!
# {'D_loss': 1.0, 'G_loss': 0.9999823570251465}
# [Client 1, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998647
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998122
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998873
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998397
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998969
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998319
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999171
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998760
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998981
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999762
# Avg one epoch time: 1.27, total 10 epochs time: 12.70
# Training finish!
# {'D_loss': 1.0202847594564801e-10, 'G_loss': 0.999997615814209}
# [Client 2, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998534
# Epoch: [ 2] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998534
# Epoch: [ 3] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998176
# Epoch: [ 4] [  50/  50] D_loss: 1.00000000, G_loss: 0.99994534
# Epoch: [ 5] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998635
# Epoch: [ 6] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999046
# Epoch: [ 7] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998856
# Epoch: [ 8] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998665
# Epoch: [ 9] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998397
# Epoch: [10] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999344
# Avg one epoch time: 1.37, total 10 epochs time: 13.72
# Training finish!
# {'D_loss': 1.0, 'G_loss': 0.9999934434890747}
# [Client 3, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997532
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996865
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997586
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999273
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999219
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997270
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999046
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999225
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999350
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998999
# Avg one epoch time: 1.36, total 10 epochs time: 13.56
# Training finish!
# {'D_loss': 1.590336196066744e-11, 'G_loss': 0.9999899864196777}
# [Client 4, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996698
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998057
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999410
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998677
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996948
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998796
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998397
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998987
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999046
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999303
# Avg one epoch time: 1.49, total 10 epochs time: 14.93
# Training finish!
# {'D_loss': 1.1135027622177773e-10, 'G_loss': 0.9999930262565613}
# [Client 5, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.20000002, G_loss: 0.99916685
# Epoch: [ 2] [  50/  50] D_loss: 0.20000020, G_loss: 0.99996674
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998397
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99989092
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99994791
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998951
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99976027
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99992436
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99988097
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995643
# Avg one epoch time: 1.23, total 10 epochs time: 12.32
# Training finish!
# {'D_loss': 1.2579247643529357e-09, 'G_loss': 0.9999564290046692}
# [Client 6, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998772
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99984729
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997413
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99991000
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997389
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998492
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998724
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998397
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996203
# Epoch: [10] [  50/  50] D_loss: 0.20000000, G_loss: 0.99998170
# Avg one epoch time: 1.23, total 10 epochs time: 12.26
# Training finish!
# {'D_loss': 0.20000000298023224, 'G_loss': 0.999981701374054}
# [Client 7, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99995309
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999046
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998653
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997532
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998647
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999255
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997091
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998933
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999237
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999917
# Avg one epoch time: 1.21, total 10 epochs time: 12.08
# Training finish!
# {'D_loss': 6.702020015347809e-12, 'G_loss': 0.9999991655349731}
# [Client 8, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998838
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997586
# Epoch: [ 3] [  50/  50] D_loss: 0.20000000, G_loss: 0.99998772
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998474
# Epoch: [ 5] [  50/  50] D_loss: 0.20000000, G_loss: 0.99997795
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998665
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996793
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997616
# Epoch: [ 9] [  50/  50] D_loss: 0.20000000, G_loss: 0.99999225
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999332
# Avg one epoch time: 1.29, total 10 epochs time: 12.86
# Training finish!
# {'D_loss': 5.2173161624313735e-11, 'G_loss': 0.9999933242797852}
# [Client 9, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000002, G_loss: 0.99991399
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997967
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997997
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998587
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996138
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997842
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999332
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999255
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998778
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998891
# Avg one epoch time: 1.47, total 10 epochs time: 14.69
# Training finish!
# {'D_loss': 1.5614506909678028e-10, 'G_loss': 0.9999889135360718}
# [Client 10, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000001, G_loss: 0.99993211
# Epoch: [ 2] [  50/  50] D_loss: 0.00000022, G_loss: 0.99998587
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996626
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99996245
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999285
# Epoch: [ 6] [  50/  50] D_loss: 0.00000001, G_loss: 0.99972534
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998343
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999744
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999845
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999315
# Avg one epoch time: 1.60, total 10 epochs time: 15.96
# Training finish!
# {'D_loss': 5.456299908418449e-12, 'G_loss': 0.9999931454658508}
# [Client 11, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999207
# Epoch: [ 2] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998796
# Epoch: [ 3] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998730
# Epoch: [ 4] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997699
# Epoch: [ 5] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999124
# Epoch: [ 6] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999219
# Epoch: [ 7] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997777
# Epoch: [ 8] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999177
# Epoch: [ 9] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998826
# Epoch: [10] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999106
# Avg one epoch time: 1.45, total 10 epochs time: 14.51
# Training finish!
# {'D_loss': 1.0, 'G_loss': 0.9999910593032837}
# [Client 12, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998873
# Epoch: [ 2] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998873
# Epoch: [ 3] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998844
# Epoch: [ 4] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998921
# Epoch: [ 5] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999368
# Epoch: [ 6] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999321
# Epoch: [ 7] [  50/  50] D_loss: 1.00000000, G_loss: 0.99998075
# Epoch: [ 8] [  50/  50] D_loss: 1.00000000, G_loss: 0.99997455
# Epoch: [ 9] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999392
# Epoch: [10] [  50/  50] D_loss: 1.00000000, G_loss: 0.99999028
# Avg one epoch time: 1.29, total 10 epochs time: 12.87
# Training finish!
# {'D_loss': 1.0, 'G_loss': 0.9999902844429016}
# [Client 13, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999654
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999368
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999321
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999523
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998820
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998605
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999142
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999219
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999219
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99998057
# Avg one epoch time: 1.32, total 10 epochs time: 13.23
# Training finish!
# {'D_loss': 5.126488209633573e-12, 'G_loss': 0.9999805688858032}
# [Client 14, round 2] fit, config: {'server_round': 2, 'local_epochs': 5}
# training start!!
# Epoch: [ 1] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997616
# Epoch: [ 2] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999112
# Epoch: [ 3] [  50/  50] D_loss: 0.00000000, G_loss: 0.99997723
# Epoch: [ 4] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999654
# Epoch: [ 5] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999714
# Epoch: [ 6] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999821
# Epoch: [ 7] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999273
# Epoch: [ 8] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999827
# Epoch: [ 9] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999541
# Epoch: [10] [  50/  50] D_loss: 0.00000000, G_loss: 0.99999267
# Avg one epoch time: 1.26, total 10 epochs time: 12.63
# Training finish!
# {'D_loss': 8.043405941293713e-10, 'G_loss': 0.9999926686286926}
# length of trainset 5284, length of testset1321
# Accuracy for fold 1 : 0.6056018168054504
# length of trainset 5284, length of testset1321
# Accuracy for fold 2 : 0.5904617713853142
# length of trainset 5284, length of testset1321
# Accuracy for fold 3 : 0.6495079485238455
# length of trainset 5284, length of testset1321
# Accuracy for fold 4 : 0.7070401211203634
# length of trainset 5284, length of testset1321
# Accuracy for fold 5 : 0.6714610143830432
# round2 accuracy:0.5962290999644255

# %% [markdown]
# #Train models with IID and non-IID data
